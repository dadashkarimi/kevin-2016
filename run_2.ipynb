# %%
# !./run.sh -1
# Out:
# This script is an example of a fully automated motion correction of the
# fetal brain, as described in "Automated Fetal Brain Segmentation from 2D MRI
# Slices for Motion Correction", K. Keraudren et al. (2014)
#
# Performing brain detection
#
# Mask file already exists for data/b2_mom_001_19_week_3__T2_Haste_Cor_mm_400_FOV.nii.gz. Skipping detection.
# Mask file already exists for data/b2_mom_003_19_week_3__T2_Haste_Sag_mm_400_FOV.nii.gz. Skipping detection.
# Mask file already exists for data/b2_mom_007_22_week_5__T2_Haste_Ax__mm_400_FOV.nii.gz. Skipping detection.
# Mask file already exists for data/b2_mom_009_24_week_3__T2_Haste_Ax__mm_400_FOV.nii.gz. Skipping detection.
# Mask file already exists for data/b2_mom_010_22_week_2__body_T2_Hast_mm_400_FOV.nii.gz. Skipping detection.
# Mask file already exists for data/b2_mom_012_19_week_4__body_T2_Hast_mm_400_FOV.nii.gz. Skipping detection.
# ...

# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
folder_path = "data"
for filename in os.listdir(folder_path):
    if filename.endswith(".nii.gz"):
        file_path = os.path.join(folder_path, filename)
        data = nib.load(file_path)
#         print(data.header)

#         print(np.sum(data.get_data()))
        print("Data type of the loaded image data:", data.get_data().shape)

# data = nib.load("data2/stack-6.nii.gz")
# data = data.get_data()
# data_min = np.min(data)
# data_max = np.max(data)
# print(data_min,data_max)
# print("Data type of the loaded image data:", data.shape)

data = nib.load("output_detection/b2_mom_001_19_week_3__T2_Haste_Cor_mm_400_FOV_expanded.nii.gz")
# print(data.header)
data = data.get_data()
print("Data type of the loaded image data:", data.shape,np.min(data),np.max(data))
# # data.shape
# # data = img.get_fdata()
# Out:
# ('Data type of the loaded image data:', (256, 256, 20))
# ('Data type of the loaded image data:', (256, 256, 80, 1), 0.0, 1.0)
